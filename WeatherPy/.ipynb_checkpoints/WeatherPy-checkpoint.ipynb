# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pingouin as pg
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
cities
# Out:
# 638
# ['punta arenas',
#  'pevek',
#  'avarua',
#  'busselton',
#  'bredasdorp',
#  'albany',
#  'ushuaia',
#  'port alfred',
#  'rikitea',
#  'hermanus',
#  'avera',
#  'gimli',
#  'talnakh',
#  'miles city',
#  'kodiak',
#  'podolinec',
#  'beringovskiy',
#  'belushya guba',
#  'grand gaube',
#  'eskasem',
#  'ribeira grande',
#  'bengkulu',
#  'flinders',
#  'ban nahin',
#  'rosarito',
#  'hithadhoo',
#  'butaritari',
#  'san jose',
#  'samarai',
#  'provideniya',
#  'bambous virieux',
#  'klaksvik',
#  'sumbe',
#  'nouadhibou',
#  'morros',
#  'barrow',
#  'hasaki',
#  'cookeville',
#  'amderma',
#  'lujiang',
#  'floro',
#  'hilo',
#  'tuktoyaktuk',
#  'victoria',
#  'illoqqortoormiut',
#  'guerrero negro',
#  'kiunga',
#  'nome',
#  'eisiskes',
#  'cap-aux-meules',
#  'pangnirtung',
#  'kavaratti',
#  'norman wells',
#  'vila franca do campo',
#  'port blair',
#  'chapais',
#  'nikolskoye',
#  'lavrentiya',
#  'opotiki',
#  'tan an',
#  'saint-philippe',
#  'quatre cocos',
#  'ancud',
#  'kazalinsk',
#  'torbay',
#  'kargasok',
#  'mataura',
#  'bluff',
#  'prince rupert',
#  'bargal',
#  'saleaula',
#  'lasa',
#  'narsaq',
#  'khatanga',
#  'sar-e pul',
#  'saskylakh',
#  'clarence town',
#  'kapaa',
#  'buraydah',
#  'the valley',
#  'tsihombe',
#  'byron bay',
#  'northam',
#  'falealupo',
#  'vaini',
#  'faya',
#  'grand river south east',
#  'constantine',
#  'namatanai',
#  'benguela',
#  'ponta do sol',
#  'chuy',
#  'santa marta',
#  'adrar',
#  'touros',
#  'portland',
#  'pangai',
#  'puerto ayora',
#  'sentyabrskiy',
#  'hay river',
#  'beloha',
#  'saint-francois',
#  'beaufort',
#  'hoquiam',
#  'basco',
#  'kawalu',
#  'anadyr',
#  'chokurdakh',
#  'san carlos de bariloche',
#  'kedrovyy',
#  'hamilton',
#  'thompson',
#  'khorramshahr',
#  'flin flon',
#  'siraha',
#  'wanning',
#  'ngunguru',
#  'dossor',
#  'chagda',
#  'kosh-agach',
#  'shwebo',
#  'luganville',
#  'lagoa',
#  'lebu',
#  'saryshagan',
#  'faanui',
#  'broken hill',
#  'padang',
#  'hobart',
#  'cape town',
#  'cockburn town',
#  'ust-kuyga',
#  'taoudenni',
#  'katsuura',
#  'raudeberg',
#  'dikson',
#  'itaituba',
#  'kaoma',
#  'ostrovnoy',
#  'foldeak',
#  'kavieng',
#  'yellowknife',
#  'luderitz',
#  'mizpe ramon',
#  'roebourne',
#  'bubaque',
#  'kruisfontein',
#  'ilulissat',
#  'felipe carrillo puerto',
#  'aklavik',
#  'dianopolis',
#  'pavlovsk',
#  'magdagachi',
#  'rognan',
#  'vaitape',
#  'tefe',
#  'fontaine',
#  'severo-kurilsk',
#  'warqla',
#  'binghamton',
#  'tumannyy',
#  'quesnel',
#  'sambhar',
#  'lata',
#  'halifax',
#  'rio tinto',
#  'buribay',
#  'carnarvon',
#  'nanortalik',
#  'qaanaaq',
#  'vestmanna',
#  'madang',
#  'jennings',
#  'labuan',
#  'miri',
#  'taolanaro',
#  'chake chake',
#  'toungoo',
#  'necochea',
#  'djambala',
#  'kieta',
#  'leningradskiy',
#  'port elizabeth',
#  'saint george',
#  'jamestown',
#  'castro',
#  'les cayes',
#  'magadan',
#  'kaitangata',
#  'clyde river',
#  'dakar',
#  'mahebourg',
#  'fereydunshahr',
#  'batticaloa',
#  'kuala terengganu',
#  'tuatapere',
#  'lazaro cardenas',
#  'andenes',
#  'malakal',
#  'ormara',
#  'tiksi',
#  'antofagasta',
#  'roma',
#  'new norfolk',
#  'marsa matruh',
#  'puerto ayacucho',
#  'belaya gora',
#  'east london',
#  'gazni',
#  'olafsvik',
#  'san rafael',
#  'winslow',
#  'huangyan',
#  'calderitas',
#  'yaan',
#  'miandrivazo',
#  'carros',
#  'te anau',
#  'pisco',
#  'vastervik',
#  'nurlat',
#  'khandyga',
#  'tupaciguara',
#  'storforshei',
#  'lauro muller',
#  'suntar',
#  'louisbourg',
#  'yar-sale',
#  'tilichiki',
#  'ulaangom',
#  'tirumullaivasal',
#  'uyuni',
#  'evensk',
#  'atuona',
#  'ilave',
#  'puerto del rosario',
#  'bolungarvik',
#  'bar harbor',
#  'pochutla',
#  'giresun',
#  'lushunkou',
#  'grand centre',
#  'kaffrine',
#  'cidreira',
#  'hami',
#  'cherskiy',
#  'betare oya',
#  'mount isa',
#  'nizhneyansk',
#  'verkhnyaya inta',
#  'sao filipe',
#  'toronto',
#  'mar del plata',
#  'husavik',
#  'sayyan',
#  'saldanha',
#  'tsiroanomandidy',
#  'bilma',
#  'bathsheba',
#  'vokhma',
#  'tiznit',
#  'comodoro rivadavia',
#  'tucuman',
#  'tasiilaq',
#  'genhe',
#  'blythe',
#  'huescar',
#  'tessalit',
#  'mabamba',
#  'lagos',
#  'soyo',
#  'kahului',
#  'manokwari',
#  'palabuhanratu',
#  'longyearbyen',
#  'hambantota',
#  'cayenne',
#  'dingle',
#  'tierra blanca',
#  'plakhtiyivka',
#  'turukhansk',
#  'whitianga',
#  'thinadhoo',
#  'bridgetown',
#  'biak',
#  'aljezur',
#  'umzimvubu',
#  'cabo san lucas',
#  'rawson',
#  'gurupi',
#  'ponta delgada',
#  'vaitupu',
#  'sola',
#  'paamiut',
#  'san policarpo',
#  'paracuru',
#  'dunedin',
#  'malaryta',
#  'codrington',
#  'poum',
#  'georgetown',
#  'quixeramobim',
#  'tatsinskaya',
#  'sao joao da barra',
#  'san quintin',
#  'ngukurr',
#  'alofi',
#  'general pico',
#  'atambua',
#  'fort nelson',
#  'college',
#  'seoul',
#  'ixtapa',
#  'bethel',
#  'tateyama',
#  'inhambane',
#  'yarada',
#  'omboue',
#  'missoula',
#  'cam ranh',
#  'bandarbeyla',
#  'eureka',
#  'waipawa',
#  'nunoa',
#  'jumla',
#  'juneau',
#  'mehamn',
#  'maceio',
#  'raga',
#  'iqaluit',
#  'grindavik',
#  'kozhevnikovo',
#  'gagino',
#  'ahmadpur east',
#  'solnechnyy',
#  'arlit',
#  'ushumun',
#  'kant',
#  'sibolga',
#  'isangel',
#  'temir',
#  'rapid valley',
#  'martil',
#  'margate',
#  'canon city',
#  'skelleftea',
#  'okhotsk',
#  'upernavik',
#  'igarka',
#  'lahij',
#  'shihezi',
#  'senden',
#  'yumen',
#  'rio gallegos',
#  'jidong',
#  'oranjemund',
#  'paucartambo',
#  'kuching',
#  'sorland',
#  'juan lacaze',
#  'muisne',
#  'formoso do araguaia',
#  'mizur',
#  'tura',
#  'plettenberg bay',
#  'sao jose da coroa grande',
#  'fortuna',
#  'katobu',
#  'belem de sao francisco',
#  'pak phanang',
#  'say',
#  'kharian',
#  'burnie',
#  'korla',
#  'kartuzy',
#  'makakilo city',
#  'masjed-e soleyman',
#  'berlevag',
#  'yining',
#  'yulara',
#  'acajutla',
#  'altea',
#  'meulaboh',
#  'sorvag',
#  'shelburne',
#  'manaus',
#  'san juan',
#  'barawe',
#  'foumban',
#  'acuna',
#  'kamskiye polyany',
#  'olavarria',
#  'kulmbach',
#  'sterling',
#  'sweetwater',
#  'sa kaeo',
#  'christchurch',
#  'vryburg',
#  'saint anthony',
#  'souillac',
#  'attawapiskat',
#  'sarkand',
#  'riohacha',
#  'salalah',
#  'karamea',
#  'chara',
#  'nasriganj',
#  'onega',
#  'uren',
#  'twin falls',
#  'jaru',
#  'ahipara',
#  'hihifo',
#  'xining',
#  'aksarka',
#  'rosario oeste',
#  'esperance',
#  'hit',
#  'myanaung',
#  'shache',
#  'hammerfest',
#  'ialibu',
#  'alice springs',
#  'gazanjyk',
#  'jiuquan',
#  'biltine',
#  'srednekolymsk',
#  'lompoc',
#  'waiuku',
#  'macheng',
#  'demmin',
#  'pacific grove',
#  'kosa',
#  'kaseda',
#  'uthal',
#  'tarko-sale',
#  'namtsy',
#  'da nang',
#  'sandakan',
#  'zhanatas',
#  'cap malheureux',
#  'los llanos de aridane',
#  'khuzhir',
#  'trincomalee',
#  'kushmurun',
#  'waddan',
#  'bafra',
#  'mahaena',
#  'robertsport',
#  'ilhabela',
#  'havelock',
#  'novooleksiyivka',
#  'canutama',
#  'barentsburg',
#  'vuktyl',
#  'tambura',
#  'yambio',
#  'mys shmidta',
#  'vestmannaeyjar',
#  'griffith',
#  'statesboro',
#  'kosonsoy',
#  'olivet',
#  'palmas bellas',
#  'thyboron',
#  'makubetsu',
#  'centralia',
#  'tomatlan',
#  'shasta lake',
#  'saint-pierre',
#  'arraial do cabo',
#  'fairbanks',
#  'grande prairie',
#  'paka',
#  'damietta',
#  'carikar',
#  'vardo',
#  'linkou',
#  'ambilobe',
#  'gizo',
#  'barmer',
#  'port-gentil',
#  'ryotsu',
#  'port-de-paix',
#  'pahrump',
#  'itarema',
#  'alekseyevsk',
#  'eugene',
#  'demba',
#  'ovsyanka',
#  'hofn',
#  'matara',
#  'san antonio del norte',
#  'quime',
#  'bairiki',
#  'alfred',
#  'presidencia roque saenz pena',
#  'takoradi',
#  'talcahuano',
#  'gogrial',
#  'mae sot',
#  'mamallapuram',
#  'kisangani',
#  'kristiansund',
#  'elk city',
#  'innisfail',
#  'orlik',
#  'locri',
#  'kirakira',
#  'riyadh',
#  'walvis bay',
#  'talawakele',
#  'sept-iles',
#  'krasnogvardeyskiy',
#  'akureyri',
#  'north platte',
#  'zhigansk',
#  'veraval',
#  'goderich',
#  'zharkent',
#  'karamay',
#  'san cristobal',
#  'emerald',
#  'russell',
#  'saint andrews',
#  'geraldton',
#  'yerbogachen',
#  'leczyca',
#  'tosham',
#  'port-cartier',
#  'inirida',
#  'kysyl-syr',
#  'gangotri',
#  'prado',
#  'sabzevar',
#  'cotonou',
#  'jahrom',
#  'tevaitoa',
#  'westport',
#  'khani',
#  'amot',
#  'sorong',
#  'champerico',
#  'gat',
#  'vao',
#  'aldan',
#  'amapa',
#  'nemuro',
#  'inongo',
#  'morehead',
#  'deputatskiy',
#  'kupang',
#  'port moresby',
#  'koumac',
#  'praia da vitoria',
#  'katherine',
#  'alihe',
#  'puerto gaitan',
#  'puerto carreno',
#  'kamenskoye',
#  'samana',
#  'kita',
#  'khartoum',
#  'mapiri',
#  'tala',
#  'lorengau',
#  'nalut',
#  'lichtenburg',
#  'mergui',
#  'ketchenery',
#  'shingu',
#  'karratha',
#  'zaranj',
#  'gebre guracha',
#  'laguna',
#  'jimma',
#  'aksu',
#  'rosario do sul',
#  'aswan',
#  'rockland',
#  'beruni',
#  'sur',
#  'mayo',
#  'merauke',
#  'jujuy',
#  'qobustan',
#  'batesville',
#  'vila velha',
#  'kihei',
#  'joao pinheiro',
#  'pankovka',
#  'ahumada',
#  'yirol',
#  'atasu',
#  'vanimo',
#  'baherden',
#  'farafenni',
#  'zhezkazgan',
#  'carbonia',
#  'palmer',
#  'milkovo',
#  'japura',
#  'banda aceh',
#  'mandalgovi',
#  'le port',
#  'terekli-mekteb',
#  'kamenka',
#  'aasiaat',
#  'oussouye',
#  'safford',
#  'horta',
#  'villablino',
#  'wentzville',
#  'williston',
#  'muriti',
#  'caloundra',
#  'santa rita',
#  'lima',
#  'yanam',
#  'takestan',
#  'la ronge',
#  'urumqi',
#  'thai binh',
#  'lovozero',
#  'pringsewu',
#  'brae',
#  'north bend',
#  'minna',
#  'carutapera',
#  'charters towers',
#  'kologriv',
#  'huarmey',
#  'broome',
#  'marienburg',
#  'abu dhabi',
#  'ust-nera',
#  'loiza',
#  'naral']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_list = []
temps_list = []

url = "http://api.openweathermap.org/data/2.5/weather?"
#print(requests.get(url))
for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

    
    try:
        temp = weather_json["main"]["temp"]
        print(f"The temperature in {city} is {temp} C.")
        cities_list.append(city)
        temps_list.append(temp)
        # weatherCities_df = pd.DataFrame(temp)
        # weatherCities_df
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

#weatherCities_df = pd.DataFrame(temp)
# Out:
# The temperature in punta arenas is 283.95 C.
# The temperature in pevek is 250.07 C.
# The temperature in avarua is 300.15 C.
# The temperature in busselton is 293.71 C.
# The temperature in bredasdorp is 289.55 C.
# The temperature in albany is 267.13 C.
# The temperature in ushuaia is 282.15 C.
# The temperature in port alfred is 292.04 C.
# The temperature in rikitea is 298.75 C.
# The temperature in hermanus is 289.45 C.
# The temperature in avera is 287.33 C.
# The temperature in gimli is 256.77 C.
# The temperature in talnakh is 245.15 C.
# The temperature in miles city is 257.11 C.
# The temperature in kodiak is 275.15 C.
# The temperature in podolinec is 267.11 C.
# The temperature in beringovskiy is 266.64 C.
# Missing field/result... skipping.
# The temperature in grand gaube is 299.7 C.
# Missing field/result... skipping.
# The temperature in ribeira grande is 289.58 C.
# The temperature in bengkulu is 303.95 C.
# The temperature in flinders is 296.76 C.
# The temperature in ban nahin is 299.33 C.
# The temperature in rosarito is 289 C.
# The temperature in hithadhoo is 301.46 C.
# The temperature in butaritari is 302.55 C.
# The temperature in san jose is 283.51 C.
# The temperature in samarai is 305.97 C.
# The temperature in provideniya is 251.03 C.
# The temperature in bambous virieux is 299.77 C.
# The temperature in klaksvik is 279.15 C.
# The temperature in sumbe is 296.14 C.
# The temperature in nouadhibou is 292.15 C.
# The temperature in morros is 298.48 C.
# The temperature in barrow is 262.15 C.
# The temperature in hasaki is 280.48 C.
# The temperature in cookeville is 283.54 C.
# Missing field/result... skipping.
# The temperature in lujiang is 277.15 C.
# The temperature in floro is 278.24 C.
# The temperature in hilo is 295.58 C.
# The temperature in tuktoyaktuk is 252.15 C.
# The temperature in victoria is 290.05 C.
# Missing field/result... skipping.
# The temperature in guerrero negro is 290.02 C.
# The temperature in kiunga is 305.98 C.
# The temperature in nome is 259.15 C.
# The temperature in eisiskes is 273.32 C.
# The temperature in cap-aux-meules is 265.15 C.
# The temperature in pangnirtung is 242.15 C.
# The temperature in kavaratti is 300.29 C.
# The temperature in norman wells is 249.15 C.
# The temperature in vila franca do campo is 291.15 C.
# The temperature in port blair is 300.32 C.
# The temperature in chapais is 252.15 C.
# The temperature in nikolskoye is 276.17 C.
# The temperature in lavrentiya is 253 C.
# The temperature in opotiki is 299.82 C.
# The temperature in tan an is 298.15 C.
# The temperature in saint-philippe is 298.22 C.
# The temperature in quatre cocos is 299.74 C.
# The temperature in ancud is 287.15 C.
# Missing field/result... skipping.
# The temperature in torbay is 260.49 C.
# The temperature in kargasok is 257.68 C.
# The temperature in mataura is 289.82 C.
# The temperature in bluff is 289.43 C.
# The temperature in prince rupert is 275.15 C.
# Missing field/result... skipping.
# Missing field/result... skipping.
# The temperature in lasa is 263.24 C.
# The temperature in narsaq is 276.15 C.
# The temperature in khatanga is 242.13 C.
# The temperature in sar-e pul is 270.24 C.
# The temperature in saskylakh is 248.54 C.
# The temperature in clarence town is 298.19 C.
# The temperature in kapaa is 296.93 C.
# The temperature in buraydah is 284.15 C.
# The temperature in the valley is 297.95 C.
# Missing field/result... skipping.
# The temperature in byron bay is 300.72 C.
# The temperature in northam is 273.45 C.
# Missing field/result... skipping.
# The temperature in vaini is 302.15 C.
# The temperature in faya is 283.18 C.
# Missing field/result... skipping.
# The temperature in constantine is 276.15 C.
# The temperature in namatanai is 300.74 C.
# The temperature in benguela is 298.57 C.
# The temperature in ponta do sol is 287.98 C.
# The temperature in chuy is 292.04 C.
# The temperature in santa marta is 303.15 C.
# The temperature in adrar is 286.84 C.
# The temperature in touros is 299.15 C.
# The temperature in portland is 280.31 C.
# The temperature in pangai is 300.02 C.
# The temperature in puerto ayora is 299.19 C.
# Missing field/result... skipping.
# The temperature in hay river is 243.15 C.
# The temperature in beloha is 295.02 C.
# The temperature in saint-francois is 272.01 C.
# The temperature in beaufort is 302.11 C.
# The temperature in hoquiam is 281.57 C.
# The temperature in basco is 295.94 C.
# The temperature in kawalu is 300.6 C.
# The temperature in anadyr is 260 C.
# The temperature in chokurdakh is 245.8 C.
# The temperature in san carlos de bariloche is 294.15 C.
# The temperature in kedrovyy is 254.15 C.
# The temperature in hamilton is 277.35 C.
# The temperature in thompson is 250.15 C.
# The temperature in khorramshahr is 285.86 C.
# The temperature in flin flon is 255.15 C.
# The temperature in siraha is 290.94 C.
# The temperature in wanning is 295.88 C.
# The temperature in ngunguru is 297.76 C.
# The temperature in dossor is 266.06 C.
# Missing field/result... skipping.
# The temperature in kosh-agach is 250.48 C.
# The temperature in shwebo is 294.52 C.
# The temperature in luganville is 303.15 C.
# The temperature in lagoa is 290.9 C.
# The temperature in lebu is 286.46 C.
# Missing field/result... skipping.
# The temperature in faanui is 300.82 C.
# The temperature in broken hill is 300.15 C.
# The temperature in padang is 300.44 C.
# The temperature in hobart is 293.63 C.
# The temperature in cape town is 289.76 C.
# The temperature in cockburn town is 296.99 C.
# The temperature in ust-kuyga is 238.76 C.
# The temperature in taoudenni is 286.18 C.
# The temperature in katsuura is 281.22 C.
# The temperature in raudeberg is 278.03 C.
# The temperature in dikson is 245.45 C.
# The temperature in itaituba is 296.96 C.
# The temperature in kaoma is 291.02 C.
# The temperature in ostrovnoy is 260.05 C.
# The temperature in foldeak is 272.12 C.
# The temperature in kavieng is 302.29 C.
# The temperature in yellowknife is 240.25 C.
# The temperature in luderitz is 292.15 C.
# Missing field/result... skipping.
# The temperature in roebourne is 307.62 C.
# The temperature in bubaque is 298.18 C.
# The temperature in kruisfontein is 288.65 C.
# The temperature in ilulissat is 256.15 C.
# The temperature in felipe carrillo puerto is 294.31 C.
# The temperature in aklavik is 248.02 C.
# Missing field/result... skipping.
# The temperature in pavlovsk is 269.6 C.
# The temperature in magdagachi is 250.6 C.
# The temperature in rognan is 273.64 C.
# The temperature in vaitape is 300.82 C.
# The temperature in tefe is 297.17 C.
# The temperature in fontaine is 273.26 C.
# The temperature in severo-kurilsk is 265.42 C.
# Missing field/result... skipping.
# The temperature in binghamton is 270.22 C.
# Missing field/result... skipping.
# The temperature in quesnel is 255.15 C.
# The temperature in sambhar is 285.15 C.
# The temperature in lata is 284.27 C.
# The temperature in halifax is 258.89 C.
# The temperature in rio tinto is 282.84 C.
# The temperature in buribay is 264.09 C.
# The temperature in carnarvon is 300.15 C.
# The temperature in nanortalik is 272.05 C.
# The temperature in qaanaaq is 246.35 C.
# The temperature in vestmanna is 279.15 C.
# The temperature in madang is 301.98 C.
# The temperature in jennings is 272.1 C.
# The temperature in labuan is 301.43 C.
# The temperature in miri is 302.11 C.
# Missing field/result... skipping.
# The temperature in chake chake is 300.73 C.
# Missing field/result... skipping.
# The temperature in necochea is 292.67 C.
# The temperature in djambala is 293.82 C.
# The temperature in kieta is 302.54 C.
# The temperature in leningradskiy is 250.97 C.
# The temperature in port elizabeth is 290.15 C.
# The temperature in saint george is 279.97 C.
# The temperature in jamestown is 275.58 C.
# The temperature in castro is 290.06 C.
# The temperature in les cayes is 299.92 C.
# The temperature in magadan is 257.05 C.
# The temperature in kaitangata is 289.99 C.
# The temperature in clyde river is 241.15 C.
# The temperature in dakar is 296.01 C.
# The temperature in mahebourg is 299.79 C.
# The temperature in fereydunshahr is 267.71 C.
# The temperature in batticaloa is 299.6 C.
# The temperature in kuala terengganu is 301.06 C.
# The temperature in tuatapere is 290.93 C.
# The temperature in lazaro cardenas is 297.38 C.
# The temperature in andenes is 271.73 C.
# The temperature in malakal is 292.88 C.
# The temperature in ormara is 294.07 C.
# The temperature in tiksi is 254.46 C.
# The temperature in antofagasta is 294.73 C.
# The temperature in roma is 268.43 C.
# The temperature in new norfolk is 293.68 C.
# The temperature in marsa matruh is 287.87 C.
# The temperature in puerto ayacucho is 296.89 C.
# The temperature in belaya gora is 242.4 C.
# The temperature in east london is 293.24 C.
# Missing field/result... skipping.
# The temperature in olafsvik is 277.48 C.
# The temperature in san rafael is 299.98 C.
# The temperature in winslow is 275.39 C.
# The temperature in huangyan is 280.92 C.
# The temperature in calderitas is 299.15 C.
# The temperature in yaan is 295.61 C.
# The temperature in miandrivazo is 297.35 C.
# The temperature in carros is 278.91 C.
# The temperature in te anau is 289.86 C.
# The temperature in pisco is 294.75 C.
# Missing field/result... skipping.
# The temperature in nurlat is 272.7 C.
# The temperature in khandyga is 245.28 C.
# The temperature in tupaciguara is 294.15 C.
# The temperature in storforshei is 273.71 C.
# The temperature in lauro muller is 288.98 C.
# The temperature in suntar is 260.86 C.
# Missing field/result... skipping.
# The temperature in yar-sale is 251.19 C.
# The temperature in tilichiki is 251.03 C.
# The temperature in ulaangom is 251.73 C.
# The temperature in tirumullaivasal is 299.79 C.
# The temperature in uyuni is 287.62 C.
# The temperature in evensk is 252.61 C.
# The temperature in atuona is 300.53 C.
# The temperature in ilave is 281.63 C.
# The temperature in puerto del rosario is 289.59 C.
# Missing field/result... skipping.
# The temperature in bar harbor is 263.19 C.
# The temperature in pochutla is 301.35 C.
# The temperature in giresun is 278.15 C.
# Missing field/result... skipping.
# Missing field/result... skipping.
# The temperature in kaffrine is 298.15 C.
# The temperature in cidreira is 296.52 C.
# The temperature in hami is 263.71 C.
# The temperature in cherskiy is 244.42 C.
# The temperature in betare oya is 291.45 C.
# The temperature in mount isa is 309.15 C.
# Missing field/result... skipping.
# The temperature in verkhnyaya inta is 256.02 C.
# The temperature in sao filipe is 294.92 C.
# The temperature in toronto is 274.32 C.
# The temperature in mar del plata is 297.23 C.
# The temperature in husavik is 275.15 C.
# The temperature in sayyan is 280.17 C.
# The temperature in saldanha is 290.15 C.
# The temperature in tsiroanomandidy is 293.32 C.
# The temperature in bilma is 284.08 C.
# The temperature in bathsheba is 299.15 C.
# The temperature in vokhma is 272.17 C.
# The temperature in tiznit is 283.47 C.
# The temperature in comodoro rivadavia is 294.15 C.
# The temperature in tucuman is 297.15 C.
# The temperature in tasiilaq is 271.15 C.
# The temperature in genhe is 252.82 C.
# The temperature in blythe is 288.81 C.
# The temperature in huescar is 282.24 C.
# The temperature in tessalit is 286.67 C.
# The temperature in mabamba is 291.31 C.
# The temperature in lagos is 300.15 C.
# The temperature in soyo is 299.11 C.
# The temperature in kahului is 294.53 C.
# The temperature in manokwari is 299.9 C.
# Missing field/result... skipping.
# The temperature in longyearbyen is 270.15 C.
# The temperature in hambantota is 297.15 C.
# The temperature in cayenne is 300.15 C.
# The temperature in dingle is 300.25 C.
# The temperature in tierra blanca is 289.26 C.
# The temperature in plakhtiyivka is 273.82 C.
# The temperature in turukhansk is 243.76 C.
# The temperature in whitianga is 302.04 C.
# The temperature in thinadhoo is 301.33 C.
# The temperature in bridgetown is 299.15 C.
# The temperature in biak is 301.23 C.
# The temperature in aljezur is 286.12 C.
# Missing field/result... skipping.
# The temperature in cabo san lucas is 293.67 C.
# The temperature in rawson is 290.35 C.
# The temperature in gurupi is 298.64 C.
# The temperature in ponta delgada is 291.15 C.
# Missing field/result... skipping.
# The temperature in sola is 305.15 C.
# The temperature in paamiut is 267.14 C.
# The temperature in san policarpo is 299.53 C.
# The temperature in paracuru is 301.04 C.
# The temperature in dunedin is 291.52 C.
# The temperature in malaryta is 274.24 C.
# The temperature in codrington is 290.5 C.
# The temperature in poum is 299.48 C.
# The temperature in georgetown is 300.53 C.
# The temperature in quixeramobim is 297.3 C.
# Missing field/result... skipping.
# The temperature in sao joao da barra is 295.75 C.
# The temperature in san quintin is 287.03 C.
# Missing field/result... skipping.
# The temperature in alofi is 301.1 C.
# The temperature in general pico is 297.61 C.
# The temperature in atambua is 301.62 C.
# The temperature in fort nelson is 249.15 C.
# The temperature in college is 243.74 C.
# The temperature in seoul is 273.46 C.
# The temperature in ixtapa is 299.2 C.
# The temperature in bethel is 271.76 C.
# The temperature in tateyama is 281.39 C.
# The temperature in inhambane is 301.31 C.
# The temperature in yarada is 292.15 C.
# The temperature in omboue is 296.67 C.
# The temperature in missoula is 271.8 C.
# The temperature in cam ranh is 299.15 C.
# The temperature in bandarbeyla is 297.8 C.
# The temperature in eureka is 285.78 C.
# The temperature in waipawa is 289.84 C.
# The temperature in nunoa is 277.19 C.
# The temperature in jumla is 267.84 C.
# The temperature in juneau is 268.47 C.
# The temperature in mehamn is 263.96 C.
# The temperature in maceio is 298.15 C.
# The temperature in raga is 289.14 C.
# The temperature in iqaluit is 244.2 C.
# The temperature in grindavik is 277.15 C.
# The temperature in kozhevnikovo is 259.41 C.
# The temperature in gagino is 269.63 C.
# The temperature in ahmadpur east is 284.82 C.
# The temperature in solnechnyy is 256.49 C.
# The temperature in arlit is 288.84 C.
# The temperature in ushumun is 251.29 C.
# The temperature in kant is 285.11 C.
# The temperature in sibolga is 302.48 C.
# The temperature in isangel is 302.15 C.
# The temperature in temir is 262.85 C.
# The temperature in rapid valley is 266.3 C.
# The temperature in martil is 289.84 C.
# The temperature in margate is 275.57 C.
# The temperature in canon city is 271.73 C.
# The temperature in skelleftea is 267.37 C.
# The temperature in okhotsk is 246.23 C.
# The temperature in upernavik is 249.32 C.
# The temperature in igarka is 245.54 C.
# The temperature in lahij is 292.69 C.
# The temperature in shihezi is 256.42 C.
# The temperature in senden is 273.05 C.
# The temperature in yumen is 266.4 C.
# The temperature in rio gallegos is 287.15 C.
# The temperature in jidong is 263.79 C.
# The temperature in oranjemund is 290.42 C.
# Missing field/result... skipping.
# The temperature in kuching is 298.15 C.
# The temperature in sorland is 277.74 C.
# The temperature in juan lacaze is 294.82 C.
# The temperature in muisne is 297.29 C.
# Missing field/result... skipping.
# The temperature in mizur is 263.9 C.
# The temperature in tura is 292.93 C.
# The temperature in plettenberg bay is 290.45 C.
# The temperature in sao jose da coroa grande is 299.95 C.
# The temperature in fortuna is 285.75 C.
# The temperature in katobu is 303.48 C.
# The temperature in belem de sao francisco is 297.57 C.
# The temperature in pak phanang is 299.15 C.
# The temperature in say is 293.15 C.
# The temperature in kharian is 280.15 C.
# The temperature in burnie is 293.12 C.
# The temperature in korla is 264.53 C.
# The temperature in kartuzy is 275 C.
# The temperature in makakilo city is 297.74 C.
# Missing field/result... skipping.
# The temperature in berlevag is 271.03 C.
# The temperature in yining is 282.09 C.
# The temperature in yulara is 303.15 C.
# The temperature in acajutla is 298.71 C.
# The temperature in altea is 284.54 C.
# The temperature in meulaboh is 300.65 C.
# Missing field/result... skipping.
# The temperature in shelburne is 272.42 C.
# The temperature in manaus is 297.65 C.
# The temperature in san juan is 303.22 C.
# Missing field/result... skipping.
# The temperature in foumban is 290.61 C.
# Missing field/result... skipping.
# The temperature in kamskiye polyany is 273.15 C.
# The temperature in olavarria is 297.59 C.
# The temperature in kulmbach is 273.7 C.
# The temperature in sterling is 274.41 C.
# The temperature in sweetwater is 295.31 C.
# The temperature in sa kaeo is 302.94 C.
# The temperature in christchurch is 293.78 C.
# The temperature in vryburg is 291.24 C.
# The temperature in saint anthony is 256.36 C.
# The temperature in souillac is 299.79 C.
# Missing field/result... skipping.
# The temperature in sarkand is 264.43 C.
# The temperature in riohacha is 303.15 C.
# The temperature in salalah is 295.15 C.
# Missing field/result... skipping.
# The temperature in chara is 249.99 C.
# The temperature in nasriganj is 288.33 C.
# The temperature in onega is 271.4 C.
# The temperature in uren is 271.69 C.
# The temperature in twin falls is 269.82 C.
# The temperature in jaru is 297.86 C.
# The temperature in ahipara is 303.71 C.
# Missing field/result... skipping.
# The temperature in xining is 264.68 C.
# The temperature in aksarka is 247.69 C.
# The temperature in rosario oeste is 298.35 C.
# The temperature in esperance is 292.15 C.
# The temperature in hit is 281.22 C.
# The temperature in myanaung is 296.92 C.
# The temperature in shache is 266.23 C.
# The temperature in hammerfest is 269.15 C.
# The temperature in ialibu is 298.19 C.
# The temperature in alice springs is 301.15 C.
# The temperature in gazanjyk is 274.4 C.
# The temperature in jiuquan is 264.05 C.
# The temperature in biltine is 287.53 C.
# The temperature in srednekolymsk is 243.43 C.
# The temperature in lompoc is 287.44 C.
# The temperature in waiuku is 299.1 C.
# The temperature in macheng is 281.13 C.
# The temperature in demmin is 276.11 C.
# The temperature in pacific grove is 284.4 C.
# The temperature in kosa is 260.22 C.
# The temperature in kaseda is 280 C.
# The temperature in uthal is 287.57 C.
# The temperature in tarko-sale is 245.93 C.
# The temperature in namtsy is 238.15 C.
# The temperature in da nang is 296.57 C.
# The temperature in sandakan is 301.06 C.
# Missing field/result... skipping.
# The temperature in cap malheureux is 299.69 C.
# The temperature in los llanos de aridane is 290.78 C.
# The temperature in khuzhir is 262.16 C.
# The temperature in trincomalee is 296.68 C.
# The temperature in kushmurun is 261.06 C.
# The temperature in waddan is 281.98 C.
# The temperature in bafra is 274.15 C.
# Missing field/result... skipping.
# The temperature in robertsport is 300.74 C.
# The temperature in ilhabela is 297.44 C.
# The temperature in havelock is 288.61 C.
# The temperature in novooleksiyivka is 275.96 C.
# The temperature in canutama is 297.23 C.
# Missing field/result... skipping.
# The temperature in vuktyl is 256.21 C.
# The temperature in tambura is 292.24 C.
# The temperature in yambio is 291.88 C.
# Missing field/result... skipping.
# The temperature in vestmannaeyjar is 280.2 C.
# The temperature in griffith is 263.35 C.
# The temperature in statesboro is 290.61 C.
# The temperature in kosonsoy is 268.15 C.
# The temperature in olivet is 274.6 C.
# The temperature in palmas bellas is 299.71 C.
# The temperature in thyboron is 277.76 C.
# The temperature in makubetsu is 264.15 C.
# The temperature in centralia is 281.77 C.
# The temperature in tomatlan is 294.95 C.
# The temperature in shasta lake is 279.97 C.
# The temperature in saint-pierre is 298.28 C.
# The temperature in arraial do cabo is 297.11 C.
# The temperature in fairbanks is 241.49 C.
# The temperature in grande prairie is 248.15 C.
# The temperature in paka is 298.15 C.
# The temperature in damietta is 287.46 C.
# Missing field/result... skipping.
# The temperature in vardo is 270.68 C.
# The temperature in linkou is 261.87 C.
# The temperature in ambilobe is 296.87 C.
# The temperature in gizo is 301.63 C.
# The temperature in barmer is 285.6 C.
# The temperature in port-gentil is 300.65 C.
# The temperature in ryotsu is 279.3 C.
# Missing field/result... skipping.
# The temperature in pahrump is 282.41 C.
# The temperature in itarema is 298.91 C.
# The temperature in alekseyevsk is 262.3 C.
# The temperature in eugene is 282.13 C.
# The temperature in demba is 292.14 C.
# The temperature in ovsyanka is 254.15 C.
# The temperature in hofn is 279.63 C.
# The temperature in matara is 299.75 C.
# The temperature in san antonio del norte is 293.15 C.
# The temperature in quime is 283.48 C.
# The temperature in bairiki is 305.15 C.
# The temperature in alfred is 272.58 C.
# The temperature in presidencia roque saenz pena is 301.72 C.
# The temperature in takoradi is 298.05 C.
# The temperature in talcahuano is 291.15 C.
# The temperature in gogrial is 291.46 C.
# The temperature in mae sot is 292.15 C.
# The temperature in mamallapuram is 299.15 C.
# The temperature in kisangani is 293.51 C.
# The temperature in kristiansund is 278.15 C.
# The temperature in elk city is 275.35 C.
# The temperature in innisfail is 306.48 C.
# The temperature in orlik is 246.5 C.
# The temperature in locri is 286 C.
# The temperature in kirakira is 301.95 C.
# The temperature in riyadh is 285.15 C.
# The temperature in walvis bay is 291.89 C.
# The temperature in talawakele is 296.79 C.
# The temperature in sept-iles is 251.15 C.
# The temperature in krasnogvardeyskiy is 257.62 C.
# The temperature in akureyri is 275.15 C.
# The temperature in north platte is 270.51 C.
# The temperature in zhigansk is 249.18 C.
# The temperature in veraval is 288.66 C.
# The temperature in goderich is 274.26 C.
# The temperature in zharkent is 260.05 C.
# Missing field/result... skipping.
# The temperature in san cristobal is 299.15 C.
# The temperature in emerald is 307.35 C.
# The temperature in russell is 287.48 C.
# The temperature in saint andrews is 286.43 C.
# The temperature in geraldton is 304.15 C.
# The temperature in yerbogachen is 252.67 C.
# The temperature in leczyca is 275.12 C.
# The temperature in tosham is 282.45 C.
# The temperature in port-cartier is 251.15 C.
# The temperature in inirida is 297.67 C.
# The temperature in kysyl-syr is 250.36 C.
# Missing field/result... skipping.
# The temperature in prado is 299.3 C.
# The temperature in sabzevar is 274.29 C.
# The temperature in cotonou is 300.15 C.
# Missing field/result... skipping.
# The temperature in tevaitoa is 301.02 C.
# The temperature in westport is 274.02 C.
# The temperature in khani is 276.15 C.
# The temperature in amot is 270.93 C.
# The temperature in sorong is 304.09 C.
# The temperature in champerico is 303.15 C.
# The temperature in gat is 283.41 C.
# The temperature in vao is 297.99 C.
# The temperature in aldan is 255.97 C.
# The temperature in amapa is 295.56 C.
# The temperature in nemuro is 270.15 C.
# The temperature in inongo is 295.34 C.
# The temperature in morehead is 278.95 C.
# The temperature in deputatskiy is 239.23 C.
# The temperature in kupang is 301.15 C.
# The temperature in port moresby is 304.15 C.
# The temperature in koumac is 299.57 C.
# The temperature in praia da vitoria is 291.15 C.
# The temperature in katherine is 305.15 C.
# The temperature in alihe is 255.79 C.
# The temperature in puerto gaitan is 299.64 C.
# The temperature in puerto carreno is 300.57 C.
# Missing field/result... skipping.
# The temperature in samana is 295.15 C.
# The temperature in kita is 291.65 C.
# The temperature in khartoum is 289.15 C.
# The temperature in mapiri is 292.58 C.
# The temperature in tala is 282.67 C.
# The temperature in lorengau is 302.15 C.
# The temperature in nalut is 279.29 C.
# The temperature in lichtenburg is 288.68 C.
# Missing field/result... skipping.
# Missing field/result... skipping.
# The temperature in shingu is 280.15 C.
# The temperature in karratha is 302.98 C.
# The temperature in zaranj is 279.15 C.
# The temperature in gebre guracha is 286.07 C.
# The temperature in laguna is 281.96 C.
# The temperature in jimma is 286.66 C.
# The temperature in aksu is 266.84 C.
# The temperature in rosario do sul is 294.81 C.
# The temperature in aswan is 281.65 C.
# The temperature in rockland is 272.97 C.
# Missing field/result... skipping.
# The temperature in sur is 290.49 C.
# The temperature in mayo is 274.78 C.
# The temperature in merauke is 306.05 C.
# Missing field/result... skipping.
# The temperature in qobustan is 277.15 C.
# The temperature in batesville is 277.67 C.
# The temperature in vila velha is 297.92 C.
# The temperature in kihei is 294.2 C.
# The temperature in joao pinheiro is 295.43 C.
# The temperature in pankovka is 275.56 C.
# Missing field/result... skipping.
# Missing field/result... skipping.
# The temperature in atasu is 265.69 C.
# The temperature in vanimo is 301.13 C.
# The temperature in baherden is 274.67 C.
# The temperature in farafenni is 294.01 C.
# The temperature in zhezkazgan is 266.15 C.
# The temperature in carbonia is 282.1 C.
# The temperature in palmer is 265.95 C.
# The temperature in milkovo is 262.83 C.
# The temperature in japura is 303.6 C.
# The temperature in banda aceh is 302.42 C.
# The temperature in mandalgovi is 259.64 C.
# The temperature in le port is 298.15 C.
# The temperature in terekli-mekteb is 272.52 C.
# The temperature in kamenka is 273.15 C.
# The temperature in aasiaat is 254 C.
# The temperature in oussouye is 293.51 C.
# The temperature in safford is 283.33 C.
# The temperature in horta is 289.58 C.
# The temperature in villablino is 275.65 C.
# The temperature in wentzville is 272.04 C.
# The temperature in williston is 249.91 C.
# The temperature in muriti is 294.15 C.
# The temperature in caloundra is 301.15 C.
# The temperature in santa rita is 300.15 C.
# The temperature in lima is 295.15 C.
# The temperature in yanam is 295.15 C.
# The temperature in takestan is 273.15 C.
# The temperature in la ronge is 253.15 C.
# The temperature in urumqi is 253.15 C.
# The temperature in thai binh is 290.15 C.
# The temperature in lovozero is 257.3 C.
# The temperature in pringsewu is 301.48 C.
# The temperature in brae is 279.01 C.
# The temperature in north bend is 283.3 C.
# The temperature in minna is 296.15 C.
# The temperature in carutapera is 300.99 C.
# The temperature in charters towers is 310.2 C.
# The temperature in kologriv is 272.09 C.
# The temperature in huarmey is 293.04 C.
# The temperature in broome is 270.04 C.
# The temperature in marienburg is 274.82 C.
# The temperature in abu dhabi is 288.67 C.
# The temperature in ust-nera is 232.34 C.
# The temperature in loiza is 296.5 C.
# Missing field/result... skipping.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_temps_df = pd.DataFrame(temps_list, cities_list)
#city_temps_df.to_csv('output_data/city_temps.csv')

city_temps_df
# Out:
#                    0
# punta arenas  283.95
# pevek         250.07
# avarua        300.15
# busselton     293.71
# bredasdorp    289.55
# ...              ...
# broome        270.04
# marienburg    274.82
# abu dhabi     288.67
# ust-nera      232.34
# loiza         296.50
#
# [581 rows x 1 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
