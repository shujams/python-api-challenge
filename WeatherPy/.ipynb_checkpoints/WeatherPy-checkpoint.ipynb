# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pingouin as pg # Install pingouin stats package (pip install pingouin)
import seaborn as sns # Install seaborn data visualization library (pip install seaborn)
from scipy.stats import pearsonr
import csv
import os

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
cities
# Out:
# 620
# ['nizwa',
#  'port elizabeth',
#  'dikson',
#  'barentsburg',
#  'jamestown',
#  'qaanaaq',
#  'bredasdorp',
#  'longyearbyen',
#  'union',
#  'ust-koksa',
#  'panaba',
#  'dwarka',
#  'rawson',
#  'esperance',
#  'kaitangata',
#  'palabuhanratu',
#  'xiongyue',
#  'jacksonville',
#  'new norfolk',
#  'brigantine',
#  'tungor',
#  'barrow',
#  'hilo',
#  'mys shmidta',
#  'torbay',
#  'saint-philippe',
#  'barcelos',
#  'hobart',
#  'albany',
#  'omboue',
#  'shellbrook',
#  'cape town',
#  'waipawa',
#  'martapura',
#  'cidreira',
#  'lucapa',
#  'tiksi',
#  'punta arenas',
#  'okahandja',
#  'mataura',
#  'ushuaia',
#  'klaksvik',
#  'victoria',
#  'san ignacio',
#  'grand gaube',
#  'kapaa',
#  'beyneu',
#  'kavaratti',
#  'bengkulu',
#  'rikitea',
#  'iqaluit',
#  'galle',
#  'tuktoyaktuk',
#  'busselton',
#  'brae',
#  'castro',
#  'labuhan',
#  'arraial do cabo',
#  'pevek',
#  'ilulissat',
#  'faya',
#  'saskylakh',
#  'vaini',
#  'coquimbo',
#  'carnarvon',
#  'yatou',
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_list = []
temps_list = []
lat_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
counter = 0

url = "http://api.openweathermap.org/data/2.5/weather?"
#print(requests.get(url))
for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

    
    try:
        temp = weather_json["main"]["temp"]
        lat = weather_json["coord"]["lat"]
        humidity = weather_json["main"]["humidity"]
        cloudiness = weather_json["clouds"]["all"]
        wind_speed = weather_json["wind"]["speed"]
        counter = counter + 1
        
        
        print(f"({counter}) The temperature in {city} is {temp} ºF.")
        cities_list.append(city)
        temps_list.append(temp)
        lat_list.append(lat)
        humidity_list.append(humidity)
        cloudiness_list.append(cloudiness)
        wind_speed_list.append(wind_speed)
       
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

#weatherCities_df = pd.DataFrame(temp)
# Out:
# (1) The temperature in nizwa is 54.27 ºF.
# (2) The temperature in port elizabeth is 66.2 ºF.
# (3) The temperature in dikson is -24.83 ºF.
# Missing field/result... skipping.
# (4) The temperature in jamestown is 18.64 ºF.
# (5) The temperature in qaanaaq is -18.53 ºF.
# (6) The temperature in bredasdorp is 62.92 ºF.
# (7) The temperature in longyearbyen is 19.27 ºF.
# (8) The temperature in union is 32.04 ºF.
# (9) The temperature in ust-koksa is -0.36 ºF.
# (10) The temperature in panaba is 74.14 ºF.
# (11) The temperature in dwarka is 68.34 ºF.
# (12) The temperature in rawson is 62.11 ºF.
# (13) The temperature in esperance is 66.2 ºF.
# (14) The temperature in kaitangata is 63.66 ºF.
# Missing field/result... skipping.
# (15) The temperature in xiongyue is 23.02 ºF.
# (16) The temperature in jacksonville is 59.11 ºF.
# (17) The temperature in new norfolk is 62.96 ºF.
# (18) The temperature in brigantine is 32.45 ºF.
# (19) The temperature in tungor is -5.24 ºF.
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = [cities_list, lat_list, temps_list, humidity_list, cloudiness_list, wind_speed_list]

city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df.transpose() 

city_data_df.columns = ['City', 'Latitude', 'Temperature (F)', 'Humidity (%)', 'Cloudiness (%)', 'Wind Speed (mph)']

city_data_df.to_csv('output_data/city_data.csv')

city_data_df
# Out:
#                City Latitude Temperature (F) Humidity (%) Cloudiness (%)  \
# 0             nizwa    22.93           54.27           67              0
# 1    port elizabeth   -33.92            66.2           68             75
# 2            dikson    73.51          -24.83           94             87
# 3         jamestown     42.1           18.64           78             90
# 4           qaanaaq    77.48          -18.53           47              0
# ..              ...      ...             ...          ...            ...
# 566          yabelo     4.88           68.13           43             70
# 567         rafaela   -31.25           83.52           57            100
# 568         chapais    49.78            -5.8           76              1
# 569         redmond    47.67           49.39           93              1
# 570             urk    52.66           35.22          100             75
#
#     Wind Speed (mph)
# 0               0.47
# 1               20.8
# 2               8.37
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# lat_temp = plt.scatter(lat_list, temps_list)
# plt.show()

print(pg.corr(lat_list, temps_list))

sns.regplot(lat_list, temps_list)
plt.title('City Latitude vs. Temperature (F) (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Temperature (F)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig1.png')
plt.show()
# Out:
#            n      r           CI95%     r2  adj_r2          p-val        BF10  \
# pearson  571 -0.789  [-0.82, -0.76]  0.623   0.622  1.101180e-122  7.628e+118
#
#          power
# pearson    1.0

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# lat_humidity = plt.scatter(lat_list, humidity_list)
# plt.show()

print(pg.corr(lat_list, humidity_list))

sns.regplot(lat_list, humidity_list)
plt.title('City Latitude vs. Humidity (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Humidity (%)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig2.png')
plt.show()
# Out:
#            n      r         CI95%     r2  adj_r2     p-val      BF10  power
# pearson  571  0.189  [0.11, 0.27]  0.036   0.032  0.000006  1504.443  0.995

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# lat_cloudiness = plt.scatter(lat_list, cloudiness_list)
# plt.show()

print(pg.corr(lat_list, cloudiness_list))

sns.regplot(lat_list, cloudiness_list)
plt.title('City Latitude vs. Cloudiness (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Cloudiness (%)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig3.png')
plt.show()
# Out:
#            n      r          CI95%     r2  adj_r2     p-val   BF10  power
# pearson  571  0.074  [-0.01, 0.16]  0.006   0.002  0.076143  0.252  0.427

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# lat_wind = plt.scatter(lat_list, wind_speed_list)
# plt.show()
print(pg.corr(lat_list, wind_speed_list))

sns.regplot(lat_list, wind_speed_list)
plt.title('City Latitude vs. Wind Speed (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Wind Speed (mph)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig4.png')
plt.show()
# Out:
#            n      r         CI95%   r2  adj_r2     p-val   BF10  power
# pearson  571  0.019  [-0.06, 0.1]  0.0  -0.003  0.642709  0.058  0.075

# %%
northern_df = city_data_df[city_data_df['Latitude'] >=0]
northern_df
# Out:
#              City Latitude Temperature (F) Humidity (%) Cloudiness (%)  \
# 0           nizwa    22.93           54.27           67              0
# 2          dikson    73.51          -24.83           94             87
# 3       jamestown     42.1           18.64           78             90
# 4         qaanaaq    77.48          -18.53           47              0
# 6    longyearbyen    78.22           19.27           97            100
# ..            ...      ...             ...          ...            ...
# 565  komsomolskiy    40.43           27.16           79            100
# 566        yabelo     4.88           68.13           43             70
# 568       chapais    49.78            -5.8           76              1
# 569       redmond    47.67           49.39           93              1
# 570           urk    52.66           35.22          100             75
#
#     Wind Speed (mph)
# 0               0.47
# 2               8.37
# 3              13.87
# 4               5.21
# ...

# %%
southern_df = city_data_df[city_data_df['Latitude'] < 0]
southern_df
# Out:
#                City Latitude Temperature (F) Humidity (%) Cloudiness (%)  \
# 1    port elizabeth   -33.92            66.2           68             75
# 5        bredasdorp   -34.53           62.92           88            100
# 11           rawson    -43.3           62.11           64              0
# 12        esperance   -33.87            66.2           59              0
# 13       kaitangata   -46.28           63.66           77             73
# ..              ...      ...             ...          ...            ...
# 544         kimamba    -6.78            73.4           94             40
# 545         manyana    -23.4           73.45           31              0
# 550         amuntai    -2.42            78.4           86             55
# 561         sambava   -14.27            73.6           98            100
# 567         rafaela   -31.25           83.52           57            100
#
#     Wind Speed (mph)
# 1               20.8
# 5              17.22
# 11              7.52
# ...

# %%
# x = [ x[0] for x in nothern_df['Latitude'].values]
# y = [ x[0] for x in nothern_df['Temperature (F)'].values]

x = northern_df['Latitude'].astype(int)
y = northern_df['Temperature (F)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Nothern Hemisphere City Latitude vs. Temperature (F) (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Temperature (F)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig5.png')
plt.show()
# Out:
#            n      r           CI95%     r2  adj_r2          p-val        BF10  \
# pearson  390 -0.846  [-0.87, -0.82]  0.716   0.714  5.617129e-108  1.548e+104
#
#          power
# pearson    1.0

# %%
x = southern_df['Latitude'].astype(int)
y = southern_df['Temperature (F)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Southern Hemisphere City Latitude vs. Temperature (F) (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Temperature (F)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig6.png')
plt.show()
# Out:
#            n      r         CI95%     r2  adj_r2         p-val       BF10  \
# pearson  181  0.419  [0.29, 0.53]  0.176   0.166  4.292302e-09  2.488e+06
#
#          power
# pearson    1.0

# %%
x = northern_df['Latitude'].astype(int)
y = northern_df['Humidity (%)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Nothern Hemisphere City Latitude vs. Humidity (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Humidity (%)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig7.png')
plt.show()
# Out:
#            n      r         CI95%     r2  adj_r2         p-val       BF10  \
# pearson  390  0.351  [0.26, 0.44]  0.123   0.119  9.131509e-13  6.906e+09
#
#          power
# pearson    1.0

# %%
x = southern_df['Latitude'].astype(int)
y = southern_df['Humidity (%)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Southern Hemisphere City Latitude vs. Humidity (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Humidity (%)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig8.png')
plt.show()
# Out:
#            n      r        CI95%     r2  adj_r2     p-val      BF10  power
# pearson  181  0.335  [0.2, 0.46]  0.113   0.103  0.000004  3621.189  0.997

# %%
x = northern_df['Latitude'].astype(int)
y = northern_df['Cloudiness (%)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Nothern Hemisphere City Latitude vs. Cloudiness (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Cloudiness (%)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig9.png')
plt.show()
# Out:
#            n      r         CI95%     r2  adj_r2         p-val       BF10  \
# pearson  390  0.322  [0.23, 0.41]  0.104   0.099  7.166230e-11  9.769e+07
#
#          power
# pearson    1.0

# %%
x = southern_df['Latitude'].astype(int)
y = southern_df['Cloudiness (%)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Southern Hemisphere City Latitude vs. Cloudiness (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Cloudiness (%)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig10.png')
plt.show()
# Out:
#            n      r         CI95%     r2  adj_r2     p-val   BF10  power
# pearson  181  0.184  [0.04, 0.32]  0.034   0.023  0.013039  1.978  0.703

# %%
x = northern_df['Latitude'].astype(int)
y = northern_df['Wind Speed (mph)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Nothern Hemisphere City Latitude vs. Wind Speed (mph) (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Wind Speed (mph)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig11.png')
plt.show()
# Out:
#            n      r        CI95%     r2  adj_r2     p-val     BF10  power
# pearson  390  0.197  [0.1, 0.29]  0.039   0.034  0.000092  128.918  0.975

# %%
x = southern_df['Latitude'].astype(int)
y = southern_df['Wind Speed (mph)'].astype(int)

print(pg.corr(x, y))

sns.regplot(x, y)
plt.title('Southern Hemisphere City Latitude vs. Wind Speed (mph) (%s)' % time.strftime('%x'), fontsize = 15) # title with fontsize 20
plt.xlabel('Latitude (°)', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Wind Speed (mph)', fontsize = 12) # y-axis label with fontsize 15

plt.savefig('output_data/Fig12.png')
plt.show()
# Out:
#            n      r           CI95%     r2  adj_r2         p-val       BF10  \
# pearson  181 -0.393  [-0.51, -0.26]  0.155   0.145  4.367057e-08  2.662e+05
#
#          power
# pearson    1.0
